# %%
 # !pip install langchain-huggingface
 # For api call
 # !pip install huggingface_hub
 # !pip install transformers
 # !pip install accelerate
 # !pip install bitsandbytes
 # !pip install langchain

# %%
from google.colab import userdata
sec_key = userdata.get('HUGGINGFACEHUB_API_TOKEN')

# %%
# access huggingfacemodel with api
from langchain_huggingface import HuggingFaceEndpoint

# %%
import os
os.environ['HUGGINGFACEHUB_API_TOKEN'] = sec_key

# %%
# repoid means which model i want to use
repo_id= "mistralai/Mistral-7B-Instruct-v0.3"
llm = HuggingFaceEndpoint(repo_id = repo_id, max_length = 128, temperature = 0.7, token = sec_key)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
llm
# Out:
# HuggingFaceEndpoint(repo_id='mistralai/Mistral-7B-Instruct-v0.3', temperature=0.7, model_kwargs={'max_length': 128, 'token': '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'}, model='mistralai/Mistral-7B-Instruct-v0.3', client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.3', timeout=120)>, async_client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.3', timeout=120)>)

# %%
# prompt
llm.invoke("what is GENAI")
# Out:
# "?\n\nGENAI is an AI-powered platform that provides a variety of services, including language translation, text summarization, and text generation. It uses deep learning techniques to process and generate human-like text. The platform is designed to be easy to use, with a user-friendly interface and a range of customization options. It can be integrated into various applications and services to enhance their capabilities.\n\nHere's a brief overview of some of the services provided by GENAI:\n\n1. Text summarization: GENAI can automatically summarize long texts, such as articles or books, into shorter, more concise versions. This can save time and make it easier to quickly understand the main points of a text.\n2. Translation: GENAI can translate text from one language to another, including support for multiple languages. This can help people communicate more effectively across language barriers.\n3. Text generation: GENAI can generate new text based on a given prompt or input. This c
# ...

# %%
from langchain import PromptTemplate , LLMChain

question = "Who won cricket world cup in 2023?"
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template = template, input_variable = ['question'])
print(prompt)
# Out:
# input_variables=['question'] template="Question: {question}\nAnswer: Let's think step by step."

# %%
llm_chain = LLMChain(llm = llm, prompt = prompt)
print(llm_chain.invoke(question))
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 0.3.0. Use RunnableSequence, e.g., `prompt | llm` instead.
#   warn_deprecated(
# {'question': 'Who won cricket world cup in 2023?', 'text': ' First, we need to check if the data for the 2023 Cricket World Cup has been released yet. As of the time of this writing, the 2023 Cricket World Cup has not taken place, so we cannot provide the answer. Once the tournament is over and a winner has been declared, you can revisit this question and find the correct answer here.'}

# %%
#HuggingFacePipeline
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

# %%
model_id = 'gpt2'
model= AutoModelForCausalLM.from_pretrained(model_id)
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
pipe = pipeline("text-generation", model = model,  tokenizer = tokenizer,max_new_tokens = 100 )
hf = HuggingFacePipeline(pipeline = pipe)

# %%
hf.invoke("Hugginag face is what?")
# Out:
# 'Hugginag face is what? Is this a joke? It\'s almost too cool to keep saying nothing! The real story of the story is on stage. There are some who aren\'t happy but most of them want to get to see him. So who will be able to do it? But it\'s not too sure.\n\nI love a good song. Not a lot of people like songs like "A Million Dollar Dollar Man" and "This Life Is Too Good". I like the style and feel of each song.'
